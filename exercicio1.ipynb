# %% [markdown]
# ### exercicio aula 16/07

# %%
import pandas as pd

# %% [markdown]
# ### importando dados

# %%
url = "dataset/Morador.csv"

# %%
pd.read_csv(url)
# Out:
#                                                     morador_id;domicilio_id;idade;genero;grau_instrucao;atividade_morador;possui_habilitacao;portador_necessidades_especiais;setor_atividade_empresa_privada;setor_atividade_empresa_publica;fexp_morador
# 1;3;60 a 69 anos;Masculino;Ensino Fundamental I...                                               6286
# 2;3;50 a 59 anos;Feminino;Ensino Fundamental In...                                               6286
# 3;4;40 a 49 anos;Masculino;Ensino Fundamental I...                                               6147
# 4;4;18 a 19 anos;Feminino;Ensino Superior Incom...                                               6147
# 5;4;10 a 14 anos;Masculino;Ensino Fundamental I...                                               6147
# ...                                                                                               ...
# 74842;345422;0 a 4 anos;Masculino;Analfabeto;Nã...                                               8228
# ...

# %%
url = "dataset/Morador.csv"
pd.read_csv(url,sep=';')
# Out:
#        morador_id  domicilio_id            idade     genero  \
# 0               1             3     60 a 69 anos  Masculino
# 1               2             3     50 a 59 anos   Feminino
# 2               3             4     40 a 49 anos  Masculino
# 3               4             4     18 a 19 anos   Feminino
# 4               5             4     10 a 14 anos  Masculino
# ...           ...           ...              ...        ...
# 61353       74842        345422       0 a 4 anos  Masculino
# 61354       74843        345423  Mais de 80 anos  Masculino
# 61355       74844        345423     70 a 79 anos   Feminino
# 61356       74845        345423     30 a 39 anos  Masculino
# 61357       74846        345424  Mais de 80 anos  Masculino
#
#                          grau_instrucao       atividade_morador  \
# 0         Ensino Fundamental Incompleto  Aposentado/Pensionista
# 1         Ensino Fundamental Incompleto                  Outros
# ...

# %%
dados = pd.read_csv(url,sep=';')
dados
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.head()
# Out:
#    morador_id  domicilio_id         idade     genero  \
# 0           1             3  60 a 69 anos  Masculino
# 1           2             3  50 a 59 anos   Feminino
# 2           3             4  40 a 49 anos  Masculino
# 3           4             4  18 a 19 anos   Feminino
# 4           5             4  10 a 14 anos  Masculino
#
#                   grau_instrucao       atividade_morador possui_habilitacao  \
# 0  Ensino Fundamental Incompleto  Aposentado/Pensionista             Possui
# 1  Ensino Fundamental Incompleto                  Outros         Não Possui
# 2  Ensino Fundamental Incompleto    Profissional Liberal             Possui
# 3     Ensino Superior Incompleto       Estudante Regular             Possui
# 4  Ensino Fundamental Incompleto       Estudante Regular         Não Possui
#
#   portador_necessidades_especiais setor_atividade_empresa_privada  \
# 0                          Outros                             NaN
# ...

# %%
dados.tail()
# Out:
#        morador_id  domicilio_id            idade     genero  \
# 61353       74842        345422       0 a 4 anos  Masculino
# 61354       74843        345423  Mais de 80 anos  Masculino
# 61355       74844        345423     70 a 79 anos   Feminino
# 61356       74845        345423     30 a 39 anos  Masculino
# 61357       74846        345424  Mais de 80 anos  Masculino
#
#                          grau_instrucao       atividade_morador  \
# 61353                        Analfabeto       Não Tem Atividade
# 61354  Pós-Graduação/Mestrado/Doutorado  Aposentado/Pensionista
# 61355          Ensino Superior Completo  Aposentado/Pensionista
# 61356          Ensino Superior Completo     Funcionário Público
# 61357  Pós-Graduação/Mestrado/Doutorado  Aposentado/Pensionista
#
#       possui_habilitacao portador_necessidades_especiais  \
# 61353         Não Possui                   Não Se Aplica
# 61354             Possui                   Não Se Aplica
# ...

# %%
dados.tail(20)
# Out:
#        morador_id  domicilio_id            idade     genero  \
# 61338       74827        345419     60 a 69 anos   Feminino
# 61339       74828        345420     60 a 69 anos  Masculino
# 61340       74829        345420     50 a 59 anos   Feminino
# 61341       74830        345420     20 a 24 anos  Masculino
# 61342       74831        345420     20 a 24 anos   Feminino
# 61343       74832        345421     70 a 79 anos  Masculino
# 61344       74833        345421     70 a 79 anos   Feminino
# 61345       74834        345421     40 a 49 anos  Masculino
# 61346       74835        345421     40 a 49 anos   Feminino
# 61347       74836        345421     20 a 24 anos   Feminino
# 61348       74837        345421     20 a 24 anos   Feminino
# 61349       74838        345422     30 a 39 anos   Feminino
# 61350       74839        345422     30 a 39 anos  Masculino
# 61351       74840        345422     25 a 29 anos   Feminino
# 61352       74841        345422       5 a 9 anos   Feminino
# ...
